# %%
import pandas as pd
from gensim.models import Word2Vec
import os
import time

# 1. Lemmatize ve stem edilmiş verileri oku
df_lemma = pd.read_csv("reviews_lemmatized.csv")
df_stem = pd.read_csv("reviews_stemmed.csv")

# 2. Tokenize et
lemma_corpus = [str(sentence).split() for sentence in df_lemma["cleanedReview"].dropna()]
stem_corpus = [str(sentence).split() for sentence in df_stem["cleanedReview"].dropna()]

# 3. Parametreler
params = [
    {'model_type': 'cbow', 'window': 2, 'vector_size': 100},
    {'model_type': 'skipgram', 'window': 2, 'vector_size': 100},
    {'model_type': 'cbow', 'window': 4, 'vector_size': 100},
    {'model_type': 'skipgram', 'window': 4, 'vector_size': 100},
    {'model_type': 'cbow', 'window': 2, 'vector_size': 300},
    {'model_type': 'skipgram', 'window': 2, 'vector_size': 300},
    {'model_type': 'cbow', 'window': 4, 'vector_size': 300},
    {'model_type': 'skipgram', 'window': 4, 'vector_size': 300}
]

# 4. Model eğitim ve kaydetme
def train_models(corpus, corpus_type):
    print(f"\n {corpus_type.upper()} veri seti ile model eğitimi başlıyor\n")

    # models klasörünü oluştur
    os.makedirs("models0", exist_ok=True)

    for p in params:
        sg = 1 if p['model_type'] == 'skipgram' else 0
        model_name = f"{corpus_type}_{p['model_type']}_win{p['window']}_dim{p['vector_size']}.model"
        model_path = os.path.join("models0", model_name)

        start = time.time()
        model = Word2Vec(
            sentences=corpus,
            vector_size=p['vector_size'],
            window=p['window'],
            sg=sg,
            min_count=1,
            workers=4,
            epochs=10
        )
        end = time.time()
        model.save(model_path)

        print(f"✅ Model: {model_name}")
        print(f"   ➤ Model Türü     : {p['model_type']}")
        print(f"   ➤ Window         : {p['window']}")
        print(f"   ➤ Vektör Boyutu  : {p['vector_size']}")
        print(f"   ➤ Eğitim Süresi  : {round(end - start, 2)} saniye")
        print(f"   ➤ Vocab Uzunluğu : {len(model.wv)}")

        if "music" in model.wv:
            print(f"   ➤ 'music' kelimesine en yakın 5 kelime:")
            for word, sim in model.wv.most_similar("music", topn=5):
                print(f"     {word} ({sim:.3f})")
        else:
            print("   ➤ 'music' kelimesi modelde bulunamadı.")
        print("-" * 60)

# 5. Tüm modelleri sırayla eğit
train_models(lemma_corpus, "lemmatized")
train_models(stem_corpus, "stemmed")
# Out:
#  LEMMATIZED veri seti ile model eğitimi başlıyor
#
# ✅ Model: lemmatized_cbow_win2_dim100.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 7.92 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      songs (0.678)
#      musics (0.667)
#      song (0.642)
#      tracks (0.538)
#      games (0.506)
# ------------------------------------------------------------
# ✅ Model: lemmatized_skipgram_win2_dim100.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 14.37 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.806)
#      musics (0.770)
#      musicpodcast (0.766)
#      musici (0.723)
#      jams (0.718)
# ------------------------------------------------------------
# ✅ Model: lemmatized_cbow_win4_dim100.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 7.63 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      songs (0.666)
#      musics (0.641)
#      song (0.594)
#      tracks (0.508)
#      stuff (0.489)
# ------------------------------------------------------------
# ✅ Model: lemmatized_skipgram_win4_dim100.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 22.66 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.791)
#      musics (0.780)
#      musicpodcast (0.743)
#      musici (0.729)
#      musicand (0.722)
# ------------------------------------------------------------
# ✅ Model: lemmatized_cbow_win2_dim300.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 11.57 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      songs (0.621)
#      musics (0.608)
#      song (0.583)
#      tracks (0.505)
#      stuff (0.491)
# ------------------------------------------------------------
# ✅ Model: lemmatized_skipgram_win2_dim300.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 22.82 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.736)
#      musicpodcast (0.704)
#      musics (0.668)
#      musicand (0.655)
#      musi (0.651)
# ------------------------------------------------------------
# ✅ Model: lemmatized_cbow_win4_dim300.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 11.17 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musics (0.609)
#      songs (0.589)
#      song (0.523)
#      stuff (0.477)
#      tunes (0.472)
# ------------------------------------------------------------
# ✅ Model: lemmatized_skipgram_win4_dim300.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 32.45 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.715)
#      songsmusic (0.653)
#      musice (0.649)
#      musici (0.649)
#      musicpodcast (0.648)
# ------------------------------------------------------------
#
#  STEMMED veri seti ile model eğitimi başlıyor
#
# ✅ Model: stemmed_cbow_win2_dim100.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 7.36 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      songs (0.682)
#      musics (0.676)
#      song (0.641)
#      tracks (0.518)
#      podcast (0.493)
# ------------------------------------------------------------
# ✅ Model: stemmed_skipgram_win2_dim100.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 14.0 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.807)
#      musics (0.785)
#      musicpodcast (0.771)
#      musici (0.725)
#      musice (0.722)
# ------------------------------------------------------------
# ✅ Model: stemmed_cbow_win4_dim100.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 7.33 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      songs (0.655)
#      musics (0.625)
#      song (0.571)
#      tracks (0.538)
#      tunes (0.490)
# ------------------------------------------------------------
# ✅ Model: stemmed_skipgram_win4_dim100.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 100
#    ➤ Eğitim Süresi  : 20.91 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.782)
#      musics (0.744)
#      musicpodcast (0.743)
#      musici (0.741)
#      worldwide (0.734)
# ------------------------------------------------------------
# ✅ Model: stemmed_cbow_win2_dim300.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 10.2 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musics (0.619)
#      songs (0.613)
#      song (0.570)
#      tracks (0.522)
#      stuff (0.483)
# ------------------------------------------------------------
# ✅ Model: stemmed_skipgram_win2_dim300.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 2
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 21.11 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.723)
#      musicpodcast (0.703)
#      musics (0.678)
#      musice (0.673)
#      musicand (0.671)
# ------------------------------------------------------------
# ✅ Model: stemmed_cbow_win4_dim300.model
#    ➤ Model Türü     : cbow
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 11.01 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musics (0.576)
#      songs (0.564)
#      song (0.508)
#      tracks (0.473)
#      tunes (0.457)
# ------------------------------------------------------------
# ✅ Model: stemmed_skipgram_win4_dim300.model
#    ➤ Model Türü     : skipgram
#    ➤ Window         : 4
#    ➤ Vektör Boyutu  : 300
#    ➤ Eğitim Süresi  : 32.07 saniye
#    ➤ Vocab Uzunluğu : 28184
#    ➤ 'music' kelimesine en yakın 5 kelime:
#      musicpodcasts (0.702)
#      musicpodcast (0.668)
#      songsmusic (0.657)
#      musice (0.656)
#      worldwide (0.652)
# ------------------------------------------------------------
